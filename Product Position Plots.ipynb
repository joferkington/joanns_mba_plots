# %%
# %matplotlib inline
import data
import plots

# %%
widget0 = data.edit_product(data.center_products)
widget0
# Out:
# UWdyaWRXaWRnZXQoZ3JpZF9vcHRpb25zPXsnZGVmYXVsdENvbHVtbldpZHRoJzogMTUwLCAnaGlnaGxpZ2h0U2VsZWN0ZWRSb3cnOiBUcnVlLCAnZW5hYmxlVGV4dFNlbGVjdGlvbk9uQ2VsbHPigKY=

# %%
products = data.get_product(widget0)
fig, ax, reproject = plots.cluster_plot(['Low End', 'Traditional', 'High End'])
ax.set(title='Center Market Cluster');
plots.plot_products(ax, products, reproject);

# %%
widget1 = data.edit_product(data.size_products)
widget1
# Out:
# UWdyaWRXaWRnZXQoZ3JpZF9vcHRpb25zPXsnZGVmYXVsdENvbHVtbldpZHRoJzogMTUwLCAnaGlnaGxpZ2h0U2VsZWN0ZWRSb3cnOiBUcnVlLCAnZW5hYmxlVGV4dFNlbGVjdGlvbk9uQ2VsbHPigKY=

# %%
products = data.get_product(widget1)
fig, ax, reproject = plots.cluster_plot(['Size'])
ax.set(title='Size Market');
plots.plot_products(ax, products, reproject);

# %%
widget2 = data.edit_product(data.performance_products)
widget2
# Out:
# UWdyaWRXaWRnZXQoZ3JpZF9vcHRpb25zPXsnZGVmYXVsdENvbHVtbldpZHRoJzogMTUwLCAnaGlnaGxpZ2h0U2VsZWN0ZWRSb3cnOiBUcnVlLCAnZW5hYmxlVGV4dFNlbGVjdGlvbk9uQ2VsbHPigKY=

# %%
products = data.get_product(widget2)
fig, ax, reproject = plots.cluster_plot(['Performance'])
ax.set(title='Performance Market')
plots.plot_products(ax, products, reproject);
